# %% [markdown]
# # Assignment 3: Text Cleaning, Stopwords Removal, Stemming and Lemmatization

# %% [markdown]
# ## Problem Statement
#
# Perform text preprocessing techniques including text cleaning, stopwords removal, stemming and lemmatization using Python and the NLTK library.

# %%
# !pip install nltk scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Step 2: Download required resources (run once)
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Samiksha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Samiksha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Samiksha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import re

text = "I LOVE NLP!!! It is amazing, isn't it?"

text = text.lower()
text = re.sub(r'[^\w\s]', '', text)

print(text)
# Out:
# i love nlp it is amazing isnt it

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

words = word_tokenize(text)

filtered = [w for w in words if w not in stop_words]

print(filtered)
# Out:
# ['love', 'nlp', 'amazing', 'isnt']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Samiksha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

lemmatized = [lemmatizer.lemmatize(w) for w in filtered]

print(lemmatized)
# Out:
# ['love', 'nlp', 'amazing', 'isnt']

# %%
from sklearn.preprocessing import LabelEncoder

labels = ["car","bike","car","truck"]

encoder = LabelEncoder()

encoded = encoder.fit_transform(labels)

print(encoded)
# Out:
# [1 0 1 2]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

docs = [
"car is fast",
"bike is slow",
"truck is heavy"
]

vectorizer = TfidfVectorizer()

X = vectorizer.fit_transform(docs)

print(X.toarray())
# Out:
# [[0.         0.65249088 0.65249088 0.         0.38537163 0.
#   0.        ]
#  [0.65249088 0.         0.         0.         0.38537163 0.65249088
#   0.        ]
#  [0.         0.         0.         0.65249088 0.38537163 0.
#   0.65249088]]
